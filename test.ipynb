# %%
# !python examples/train.py --algo hatd3_sinkhorn --env mpe3d_cont --exp_name mpe3d_hatd3_sinkhorn

# %%
# !python examples/eval_mpe3d.py \
  --model /ESSD1/anhntc/UGV/HARL/results/mpe3d_cont/100x100x30-ugv4-ev2-T1000/hatd3_sinkhorn/mpe3d_hatd3_sinkhorn/seed-00001-2025-11-24-05-11-52/models \
  --episodes 1 \
  --seed 7 \
  --video_dir ./videos_eval \
  --n_ugv 4 --n_evader 2 --map_size 100 100 30
# Out:
# 2025-11-24 23:28:39.549 (   0.865s) [    7034C75E2740]vtkXOpenGLRenderWindow.:1458  WARN| bad X server connection. DISPLAY=
# [eval] n_agents=4  obs_dim=19
# [warn] failed to load actor for agent 0: /ESSD1/anhntc/UGV/HARL/results/mpe3d_cont/100x100x30-ugv4-ev2-T1000/hatd3_sinkhorn/mpe3d_hatd3_sinkhorn/seed-00001-2025-11-24-05-11-52/models/actor_agent0.pt
# [warn] failed to load actor for agent 1: /ESSD1/anhntc/UGV/HARL/results/mpe3d_cont/100x100x30-ugv4-ev2-T1000/hatd3_sinkhorn/mpe3d_hatd3_sinkhorn/seed-00001-2025-11-24-05-11-52/models/actor_agent1.pt
# [warn] failed to load actor for agent 2: /ESSD1/anhntc/UGV/HARL/results/mpe3d_cont/100x100x30-ugv4-ev2-T1000/hatd3_sinkhorn/mpe3d_hatd3_sinkhorn/seed-00001-2025-11-24-05-11-52/models/actor_agent2.pt
# [warn] failed to load actor for agent 3: /ESSD1/anhntc/UGV/HARL/results/mpe3d_cont/100x100x30-ugv4-ev2-T1000/hatd3_sinkhorn/mpe3d_hatd3_sinkhorn/seed-00001-2025-11-24-05-11-52/models/actor_agent3.pt
# ...

# %%
# !python examples/train.py --algo hatd3_sinkhorn --env mpe3d_cont --exp_name mpe3d_hatd3_sinkhorn_test \
--use_render True \
--model_dir /ESSD1/anhntc/UGV/HARL/results/mpe3d_cont/100x100x30-ugv4-ev2-T1000/hatd3_sinkhorn/mpe3d_hatd3_sinkhorn/seed-00001-2025-11-24-05-11-52/models \

# %%
# !pip install tensorboardX
